# %%
# Import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
import numpy as np
# Import PySwarms
#import pyswarms as ps
# %load_ext autoreload
# %autoreload 2

# %%
# # Store the features as X and the labels as y
# X = data.data
# y = data.target
df = pd.read_csv('cleanedData.csv')
featureList = list(df.columns)
featureList.remove('P. Habitable')
features = df[featureList].as_matrix()
target = df['P. Habitable'].as_matrix()
X = features
y = np.array(target, dtype=int)
n_inputs = 50
n_hidden = 50
n_classes = 2
y
# Out:
# /home/azhar/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':
# /home/azhar/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# Forward propagation
def forward_prop(params):
    """Forward propagation as objective function

    This computes for the forward propagation of the neural network, as
    well as the loss. It receives a set of parameters that must be
    rolled-back into the corresponding weights and biases.

    Inputs
    ------
    params: np.ndarray
        The dimensions should include an unrolled version of the
        weights and biases.

    Returns
    -------
    float
        The computed negative log-likelihood loss given the parameters
    """
    # Neural network architecture
#     n_inputs = 50
#     n_hidden = 50
#     n_classes = 2

    # Roll-back the weights and biases
    W1 = params[0:n_inputs*n_hidden].reshape((n_inputs,n_hidden))
    b1 = params[n_inputs*n_hidden:n_inputs*n_hidden+n_hidden].reshape((n_hidden,))
    W2 = params[n_inputs*n_hidden+n_hidden:n_inputs*n_hidden+n_hidden+n_hidden*n_classes].reshape((n_hidden,n_classes))
    b2 = params[n_inputs*n_hidden+n_hidden+n_hidden*n_classes:n_inputs*n_hidden+n_hidden+n_hidden*n_classes + n_classes].reshape((n_classes,))

    # Perform forward propagation
    z1 = X.dot(W1) + b1  # Pre-activation in Layer 1
    a1 = np.tanh(z1)     # Activation in Layer 1
    z2 = a1.dot(W2) + b2 # Pre-activation in Layer 2
    logits = z2          # Logits for Layer 2

    # Compute for the softmax of the logits
    exp_scores = np.exp(logits)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)

    # Compute for the negative log likelihood
    N = 3875 # Number of samples
    corect_logprobs = -np.log(probs[range(N), y])
    loss = np.sum(corect_logprobs) / N

    return loss

# %%
def f(x):
    """Higher-level method to do forward_prop in the
    whole swarm.

    Inputs
    ------
    x: numpy.ndarray of shape (n_particles, dimensions)
        The swarm that will perform the search

    Returns
    -------
    numpy.ndarray of shape (n_particles, )
        The computed loss for each particle
    """
    n_particles = x.shape[0]
    j = [forward_prop(x[i]) for i in range(n_particles)]
    return np.array(j)

# %%
# Initialize swarm
options = {'c1': 0.5, 'c2': 0.3, 'w':0.9}

# Call instance of PSO
dimensions = (n_inputs * n_hidden) + (n_hidden * n_classes) + n_hidden + n_classes
optimizer = ps.single.GlobalBestPSO(n_particles=100, dimensions=dimensions, options=options)

# Perform optimization
cost, pos = optimizer.optimize(f, iters=1000)
# Out:
# 2019-04-25 21:31:13,689 - pyswarms.single.global_best - INFO - Optimize for 1000 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
#
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|          |0/1000
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|          |0/1000, best_cost=0.0745
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|          |1/1000, best_cost=0.0745
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|          |1/1000, best_cost=0.0745
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|          |2/1000, best_cost=0.0745
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|          |2/1000, best_cost=0.0745
#
#
#
#
#
#
# pyswarms.single.global_best:   0%
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|██        |207/1000, best_cost=0.0372
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|██        |207/1000, best_cost=0.0372
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|██        |208/1000, best_cost=0.0372
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|██        |208/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|██        |209/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|██        |209/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|██        |210/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|██        |210/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|██        |211/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|██        |211/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|██        |212/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|██        |212/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|██▏       |213/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|██▏       |213/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|██▏       |214/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|██▏       |214/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|██▏       |215/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|██▏       |215/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|██▏       |216/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|██▏       |216/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|██▏       |217/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|██▏       |217/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|██▏       |218/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|██▏       |218/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|██▏       |219/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|██▏       |219/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|██▏       |220/1000, best_cost=0.0371
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|██▏       |220/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|██▏       |221/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|██▏       |221/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|██▏       |222/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|██▏       |222/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|██▏       |223/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|██▏       |223/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|██▏       |224/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|██▏       |224/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|██▎       |225/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|██▎       |225/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  23%|██▎       |226/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  23%|██▎       |226/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  23%|██▎       |227/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  23%|██▎       |227/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  23%|██▎       |228/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  23%|██▎       |228/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  23%|██▎       |229/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  23%|██▎       |229/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  23%|██▎       |230/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  23%|██▎       |230/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  23%|██▎       |231/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  23%|██▎       |231/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  23%|██▎       |232/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  23%|██▎       |232/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  23%|██▎       |233/1000, best_cost=0.037
#
#
#
#
#
#
# pyswarms.single.global_best:  23%|██▎       |233/1000, best_cost=0.0369
#
#
#
#
#
#
# pyswarms.single.global_best:  23%|██▎       |234/1000, best_cost=0.0369
#
#
#
#
#
#
# pyswarms.single.global_best:  23%|██▎       |234/1000, best_cost=0.0369
#
#
#
#
#
#
# pyswarms.single.global_best:  24%|██▎       |235/1000, best_cost=0.0369
#
#
#
#
#
#
# pyswarms.single.global_best:  24%|██▎       |235/1000, best_cost=0.0369
#
#
#
#
#
#
# pyswarms.single.global_best:  24%|██▎       |236/1000, best_cost=0.0369
#
#
#
#
#
#
# pyswarms.single.global_best:  24%|██▎       |236/1000, best_cost=0.0369
#
#
#
#
#
#
# pyswarms.single.global_best:  24%|██▎       |237/1000, best_cost=0.0369
#
#
#
#
#
#
# pyswarms.single.global_best:  24%|██▎       |237/1000, best_cost=0.0369
#
#
#
#
#
#
# pyswarms.single.global_best:  24%|██▍       |238/1000, best_cost=0.0369
#
#
#
#
#
#
# pyswarms.single.global_best:  24%|██▍       |238/1000, best_cost=0.0369
#
#
#
#
#
#
# pyswarms.single.global_best:  24%|██▍       |239/1000, best_cost=0.0369
#
#
#
#
#
#
# pyswarms.single.global_best:  24%|██▍       |239/1000, best_cost=0.0369
#
#
#
#
#
#
# pyswarms.single.global_best:  24%|██▍       |240/1000, best_cost=0.0369
#
#
#
#
#
#
# pyswarms.single.global_best:  24%|██▍       |240/1000, best_cost=0.0369
#
#
#
#
#
#
# pyswarms.single.global_best:  24%|██▍       |241/1000, best_cost=0.0369
#
#
#
#
#
#
# pyswarms.single.global_best:  24%|██▍       |241/1000, best_cost=0.0368
#
#
#
#
#
#
# pyswarms.single.global_best:  24%|██▍       |242/1000, best_cost=0.0368
#
#
#
#
#
#
# pyswarms.single.global_best:  24%|██▍       |242/1000, best_cost=0.0368
#
#
#
#
#
#
# pyswarms.single.global_best:  24%|██▍       |243/1000, best_cost=0.0368
#
#
#
#
#
#
# pyswarms.single.global_best:  24%|██▍       |243/1000, best_cost=0.0368
#
#
#
#
#
#
# pyswarms.single.global_best:  24%|██▍       |244/1000, best_cost=0.0368
#
#
#
#
#
#
# pyswarms.single.global_best:  24%|██▍       |244/1000, best_cost=0.0368
#
#
#
#
#
#
# pyswarms.single.global_best:  24%|██▍       |245/1000, best_cost=0.0368
#
#
#
#
#
#
# pyswarms.single.global_best:  24%|██▍       |245/1000, best_cost=0.0368
#
#
#
#
#
#
# pyswarms.single.global_best:  25%|██▍       |246/1000, best_cost=0.0368
#
#
#
#
#
#
# pyswarms.single.global_best:  25%|██▍       |246/1000, best_cost=0.0368
#
#
#
#
#
#
# pyswarms.single.global_best:  25%|██▍       |247/1000, best_cost=0.0368
# pyswarms.single.global_best:  25%|██▍       |247/1000, best_cost=0.0368
#
#
#
#
#
#
# pyswarms.single.global_best:  25%|██▍       |248/1000, best_cost=0.0368
#
#
#
#
#
#
# pyswarms.single.global_best:  25%|██▍       |248/1000, best_cost=0.0368
#
#
#
#
#
#
# pyswarms.single.global_best:  25%|██▍       |249/1000, best_cost=0.0368
#
#
#
#
#
#
# pyswarms.single.global_best:  25%|██▍       |249/1000, best_cost=0.0368
#
#
#
#
#
#
# pyswarms.single.global_best:  25%|██▌       |250/1000, best_cost=0.0368
#
#
#
#
#
#
# pyswarms.single.global_best:  25%|██▌       |250/1000, best_cost=0.0368
1000, best_cost=0.0367
#
#
#
#
#
#
# pyswarms.single.global_best:  30%|███       |305/1000, best_cost=0.0367
#
#
#
#
#
#
# pyswarms.single.global_best:  30%|███       |305/1000, best_cost=0.0366
#
#
#
#
#
#
# pyswarms.single.global_best:  31%|███       |306/1000, best_cost=0.0366
#
#
#
#
#
#
# pyswarms.single.global_best:  31%|███       |306/1000, best_cost=0.0366
#
#
#
#
#
#
# pyswarms.single.global_best:  31%|███       |307/1000, best_cost=0.0366
#
#
#
#
#
#
# pyswarms.single.global_best:  31%|███       |307/1000, best_cost=0.0366
#
#
#
#
#
#
# pyswarms.single.global_best:  31%|███       |308/1000, best_cost=0.0366
#
#
#
#
#
#
# ...
#
#
#
#
#
#
# pyswarms.single.global_best:  90%|████████▉ |899/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  90%|█████████ |900/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  90%|█████████ |900/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  90%|█████████ |901/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  90%|█████████ |901/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  90%|█████████ |902/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  90%|█████████ |902/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  90%|█████████ |903/1000, best_cost=0.0354
# pyswarms.single.global_best:  90%|█████████ |903/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  90%|█████████ |904/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  90%|█████████ |904/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  90%|█████████ |905/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  90%|█████████ |905/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  91%|█████████ |906/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  91%|█████████ |906/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  91%|█████████ |907/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  91%|█████████ |907/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  91%|█████████ |908/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  91%|█████████ |908/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  91%|█████████ |909/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  91%|█████████ |909/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  91%|█████████ |910/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  91%|█████████ |910/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  91%|█████████ |911/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  91%|█████████ |911/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  91%|█████████ |912/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  91%|█████████ |912/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  91%|█████████▏|913/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  91%|█████████▏|913/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  91%|█████████▏|914/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  91%|█████████▏|914/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  92%|█████████▏|915/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  92%|█████████▏|915/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  92%|█████████▏|916/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  92%|█████████▏|916/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  92%|█████████▏|917/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  92%|█████████▏|917/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  92%|█████████▏|918/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  92%|█████████▏|918/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  92%|█████████▏|919/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  92%|█████████▏|919/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  92%|█████████▏|920/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  92%|█████████▏|920/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  92%|█████████▏|921/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  92%|█████████▏|921/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  92%|█████████▏|922/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  92%|█████████▏|922/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  92%|█████████▏|923/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  92%|█████████▏|923/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  92%|█████████▏|924/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  92%|█████████▏|924/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  92%|█████████▎|925/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  92%|█████████▎|925/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  93%|█████████▎|926/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  93%|█████████▎|926/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  93%|█████████▎|927/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  93%|█████████▎|927/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  93%|█████████▎|928/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  93%|█████████▎|928/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  93%|█████████▎|929/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  93%|█████████▎|929/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  93%|█████████▎|930/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  93%|█████████▎|930/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  93%|█████████▎|931/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  93%|█████████▎|931/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  93%|█████████▎|932/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  93%|█████████▎|932/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  93%|█████████▎|933/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  93%|█████████▎|933/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  93%|█████████▎|934/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  93%|█████████▎|934/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  94%|█████████▎|935/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  94%|█████████▎|935/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  94%|█████████▎|936/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  94%|█████████▎|936/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  94%|█████████▎|937/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  94%|█████████▎|937/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  94%|█████████▍|938/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  94%|█████████▍|938/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  94%|█████████▍|939/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  94%|█████████▍|939/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  94%|█████████▍|940/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  94%|█████████▍|940/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  94%|█████████▍|941/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  94%|█████████▍|941/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  94%|█████████▍|942/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  94%|█████████▍|942/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  94%|█████████▍|943/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  94%|█████████▍|943/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  94%|█████████▍|944/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  94%|█████████▍|944/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  94%|█████████▍|945/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  94%|█████████▍|945/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  95%|█████████▍|946/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  95%|█████████▍|946/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  95%|█████████▍|947/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  95%|█████████▍|947/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  95%|█████████▍|948/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  95%|█████████▍|948/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  95%|█████████▍|949/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  95%|█████████▍|949/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  95%|█████████▌|950/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  95%|█████████▌|950/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  95%|█████████▌|951/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  95%|█████████▌|951/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  95%|█████████▌|952/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  95%|█████████▌|952/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  95%|█████████▌|953/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  95%|█████████▌|953/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  95%|█████████▌|954/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  95%|█████████▌|954/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  96%|█████████▌|955/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  96%|█████████▌|955/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  96%|█████████▌|956/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  96%|█████████▌|956/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  96%|█████████▌|957/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  96%|█████████▌|957/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  96%|█████████▌|958/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  96%|█████████▌|958/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  96%|█████████▌|959/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  96%|█████████▌|959/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  96%|█████████▌|960/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  96%|█████████▌|960/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  96%|█████████▌|961/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  96%|█████████▌|961/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  96%|█████████▌|962/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  96%|█████████▌|962/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  96%|█████████▋|963/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  96%|█████████▋|963/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  96%|█████████▋|964/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  96%|█████████▋|964/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  96%|█████████▋|965/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  96%|█████████▋|965/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  97%|█████████▋|966/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  97%|█████████▋|966/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  97%|█████████▋|967/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  97%|█████████▋|967/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  97%|█████████▋|968/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  97%|█████████▋|968/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  97%|█████████▋|969/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  97%|█████████▋|969/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  97%|█████████▋|970/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  97%|█████████▋|970/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  97%|█████████▋|971/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  97%|█████████▋|971/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  97%|█████████▋|972/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  97%|█████████▋|972/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  97%|█████████▋|973/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  97%|█████████▋|973/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  97%|█████████▋|974/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  97%|█████████▋|974/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  98%|█████████▊|975/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  98%|█████████▊|975/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  98%|█████████▊|976/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  98%|█████████▊|976/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  98%|█████████▊|977/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  98%|█████████▊|977/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  98%|█████████▊|978/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  98%|█████████▊|978/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  98%|█████████▊|979/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  98%|█████████▊|979/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  98%|█████████▊|980/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  98%|█████████▊|980/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  98%|█████████▊|981/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  98%|█████████▊|981/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  98%|█████████▊|982/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  98%|█████████▊|982/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  98%|█████████▊|983/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  98%|█████████▊|983/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  98%|█████████▊|984/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  98%|█████████▊|984/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  98%|█████████▊|985/1000, best_cost=0.0354
# pyswarms.single.global_best:  98%|█████████▊|985/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  99%|█████████▊|986/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  99%|█████████▊|986/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  99%|█████████▊|987/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  99%|█████████▊|987/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  99%|█████████▉|988/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  99%|█████████▉|988/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  99%|█████████▉|989/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  99%|█████████▉|989/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  99%|█████████▉|990/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  99%|█████████▉|990/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  99%|█████████▉|991/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  99%|█████████▉|991/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  99%|█████████▉|992/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  99%|█████████▉|992/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  99%|█████████▉|993/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  99%|█████████▉|993/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  99%|█████████▉|994/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best:  99%|█████████▉|994/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best: 100%|█████████▉|995/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best: 100%|█████████▉|995/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best: 100%|█████████▉|996/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best: 100%|█████████▉|996/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best: 100%|█████████▉|997/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best: 100%|█████████▉|997/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best: 100%|█████████▉|998/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best: 100%|█████████▉|998/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best: 100%|█████████▉|999/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best: 100%|█████████▉|999/1000, best_cost=0.0354
#
#
#
#
#
#
# pyswarms.single.global_best: 100%|██████████|1000/1000, best_cost=0.0354
#
#
#
#
#
#
# 2019-04-25 21:36:56,850 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.03535071159971234, best pos: [1.22289515 1.03691002 1.17018506 ... 0.96234026 0.81877641 1.0231421 ]

# %%
def predict(X, pos):
    """
    Use the trained weights to perform class predictions.

    Inputs
    ------
    X: numpy.ndarray
    pos: numpy.ndarray
        Position matrix found by the swarm. Will be rolled
        into weights and biases.
    """
#      n_inputs = 50
#     n_hidden = 50
#     n_classes = 2

    # Roll-back the weights and biases
    W1 = pos[0:n_inputs*n_hidden].reshape((n_inputs,n_hidden))
    b1 = pos[n_inputs*n_hidden:n_inputs*n_hidden+n_hidden].reshape((n_hidden,))
    W2 = pos[n_inputs*n_hidden+n_hidden:n_inputs*n_hidden+n_hidden+n_hidden*n_classes].reshape((n_hidden,n_classes))
    b2 = pos[n_inputs*n_hidden+n_hidden+n_hidden*n_classes:n_inputs*n_hidden+n_hidden+n_hidden*n_classes + n_classes].reshape((n_classes,))

    # Perform forward propagation
    z1 = X.dot(W1) + b1  # Pre-activation in Layer 1
    a1 = np.tanh(z1)     # Activation in Layer 1
    z2 = a1.dot(W2) + b2 # Pre-activation in Layer 2
    logits = z2          # Logits for Layer 2

    y_pred = np.argmax(logits, axis=1)
    return y_pred

# %%
(predict(X, pos) == y).mean()
# Out:
# 0.9858064516129033
